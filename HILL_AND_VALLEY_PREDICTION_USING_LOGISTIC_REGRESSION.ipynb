# %% [markdown]
# **Title of Project**
#
# Hill and Valley Prediction using Logistic Regression

# %% [markdown]
# **Objective**
#
# To predict whether a geographical feature is a hill or a valley using logistic regression.

# %% [markdown]
# **Data Source**
#
# Let's assume the data is stored in a CSV file named hill_valley.csv.

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# **Import Data**

# %%
data = pd.read_csv('/content/drive/MyDrive/YBI FOUNDATION/Hill Valley Dataset.csv')

# %% [markdown]
# **Describe Data**

# %%
print(data.head())
print(data.info())
print(data.describe())
print(data.isnull().sum())
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0     39.02     36.49     38.20     38.85     39.38     39.74     37.02
# 1      1.83      1.71      1.77      1.77      1.68      1.78      1.80
# 2  68177.69  66138.42  72981.88  74304.33  67549.66  69367.34  69169.41
# 3  44889.06  39191.86  40728.46  38576.36  45876.06  47034.00  46611.43
# 4      5.70      5.40      5.28      5.38      5.27      5.61      6.00
#
#          V8        V9       V10  ...       V92       V93       V94       V95  \
# 0     39.53     38.81     38.79  ...     36.62     36.92     38.80     38.52
# 1      1.70      1.75      1.78  ...      1.80      1.79      1.77      1.74
# 2  73268.61  74465.84  72503.37  ...  73438.88  71053.35  71112.62  74916.48
# 3  37668.32  40980.89  38466.15  ...  42625.67  40684.20  46960.73  44546.80
# 4      5.38      5.34      5.87  ...      5.17      5.67      5.60      5.94
#
#         V96       V97       V98       V99      V100  Class
# ...

# %% [markdown]
# **Data Visualization**

# %%
# Visualizing the target variable distribution
sns.countplot(data['V1'])
plt.title('Distribution of Hill and Valley Classes')
plt.show()

# Pairplot to visualize the feature relationships
# Due to high dimensionality, visualizing all features is impractical.
# For simplicity, let's visualize a subset of features.
sns.pairplot(data.iloc[:, :10], hue='V4')
plt.show()

# %% [markdown]
# **Data Preprocessing**

# %%
# Check for missing values
print(data.isnull().sum())

# Convert the target variable to numeric if it's not already
data['V1'] = data['V1'].astype(int)

# Split the data into features and target
X = data.drop('V2', axis=1)
y = data['V2']
# Out:
# V1       0
# V2       0
# V3       0
# V4       0
# V5       0
#         ..
# V97      0
# V98      0
# V99      0
# V100     0
# Class    0
# Length: 101, dtype: int64

# %% [markdown]
# **Define Target Variable (y) and Feature Variables (X)**

# %%
# Target variable
y = data['V1']

# Feature variables
X = data.drop('V1', axis=1)

# %% [markdown]
# **Train Test Split**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# **Prediction**

# %%
# Example prediction on new data
# Assuming new_data is a DataFrame with the same structure as X
# new_data = pd.DataFrame(...)

# predictions = model.predict(new_data)
# print(predictions)

# %% [markdown]
# **Explanation**
#
# The project uses logistic regression to predict whether a given geographical feature is a hill or a valley. The data is split into training and testing sets. The logistic regression model is trained on the training set and evaluated on the testing set. The model's performance is assessed using accuracy, confusion matrix, and classification report.
